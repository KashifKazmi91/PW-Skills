# %%
Q1. Write a Python function that takes in two arrays of data and calculates the F-value for a variance ratio
test. The function should return the F-value and the corresponding p-value for the test.

# %%
import numpy as np
import scipy.stats as stats

def variance_ratio_test(data1, data2):
    """
    Calculate the F-value and p-value for a variance ratio test.
    
    Parameters:
    data1 (array-like): First dataset.
    data2 (array-like): Second dataset.
    
    Returns:
    tuple: F-value and p-value for the variance ratio test.
    """
    
    # Calculate variances
    var1 = np.var(data1, ddof=1)  # Sample variance for data1
    var2 = np.var(data2, ddof=1)  # Sample variance for data2

    # Calculate the F-value (variance ratio)
    F_value = var1 / var2 if var1 >= var2 else var2 / var1
    
    # Degrees of freedom
    df1 = len(data1) - 1  # Degrees of freedom for data1
    df2 = len(data2) - 1  # Degrees of freedom for data2

    # Calculate the p-value
    p_value = stats.f.sf(F_value, df1, df2)  # Right tail p-value
    
    return F_value, p_value

# Example usage
data1 = [10, 12, 14, 15, 16]
data2 = [20, 22, 24, 25, 26]
F, p = variance_ratio_test(data1, data2)
print(f"F-value: {F}, p-value: {p}")

# %%
Q2. Given a significance level of 0.05 and the degrees of freedom for the numerator and denominator of an
F-distribution, write a Python function that returns the critical F-value for a two-tailed test.

# %%
import scipy.stats as stats

def critical_f_value(alpha, df_numerator, df_denominator):
    """
    Calculate the critical F-value for a two-tailed test.
    
    Parameters:
    alpha (float): Significance level (e.g., 0.05).
    df_numerator (int): Degrees of freedom for the numerator.
    df_denominator (int): Degrees of freedom for the denominator.
    
    Returns:
    float: Critical F-value for the two-tailed test.
    """
    # Since it's a two-tailed test, we divide the alpha by 2 for the upper tail
    critical_value = stats.f.ppf(1 - alpha / 2, df_numerator, df_denominator)
    return critical_value

# Example usage
alpha = 0.05
df_numerator = 5  # Example degrees of freedom for the numerator
df_denominator = 10  # Example degrees of freedom for the denominator
critical_value = critical_f_value(alpha, df_numerator, df_denominator)
print(f"Critical F-value: {critical_value}")

# %%
Q3. Write a Python program that generates random samples from two normal distributions with known
variances and uses an F-test to determine if the variances are equal. The program should output the F-
value, degrees of freedom, and p-value for the test.

# %%
import numpy as np
import scipy.stats as stats

def generate_samples(mean1, var1, n1, mean2, var2, n2):
    """
    Generate two random samples from normal distributions.
    
    Parameters:
    mean1 (float): Mean of the first distribution.
    var1 (float): Variance of the first distribution.
    n1 (int): Sample size for the first distribution.
    mean2 (float): Mean of the second distribution.
    var2 (float): Variance of the second distribution.
    n2 (int): Sample size for the second distribution.
    
    Returns:
    tuple: Two samples from normal distributions.
    """
    sample1 = np.random.normal(loc=mean1, scale=np.sqrt(var1), size=n1)
    sample2 = np.random.normal(loc=mean2, scale=np.sqrt(var2), size=n2)
    return sample1, sample2

def f_test(sample1, sample2):
    """
    Perform an F-test to compare variances of two samples.
    
    Parameters:
    sample1 (array-like): First sample.
    sample2 (array-like): Second sample.
    
    Returns:
    tuple: F-value, degrees of freedom, and p-value.
    """
    var1 = np.var(sample1, ddof=1)  # Sample variance for sample1
    var2 = np.var(sample2, ddof=1)  # Sample variance for sample2

    # Calculate the F-value (variance ratio)
    F_value = var1 / var2 if var1 >= var2 else var2

# %%
import scipy.stats as stats

def conduct_f_test(var1, var2, n1, n2, alpha):
    """
    Conduct an F-test to compare variances of two populations.
    
    Parameters:
    var1 (float): Variance of population 1.
    var2 (float): Variance of population 2.
    n1 (int): Sample size for population 1.
    n2 (int): Sample size for population 2.
    alpha (float): Significance level.
    
    Returns:
    tuple: F-value, critical F-value, and decision.
    """
    
    # Calculate the F-value (variance ratio)
    F_value = var1 / var2 if var1 >= var2 else var2 / var1
    
    # Degrees of freedom
    df1 = n1 - 1  # Degrees of freedom for population 1
    df2 = n2 - 1  # Degrees of freedom for population 2
    
    # Critical F-value from the F-distribution
    critical_value = stats.f.ppf(1 - alpha, df1, df2)

    # Decision
    if F_value > critical_value:
        decision = "Reject the null hypothesis (variances are significantly different)."
    else:
        decision = "Fail to reject the null hypothesis (variances are not significantly different)."
    
    return F_value, critical_value, decision

# Given data
var1 = 10  # Variance of Population 1
var2 = 15  # Variance of Population 2
n1 = 12    # Sample size for Population 1
n2 = 12    # Sample size for Population 2
alpha = 0.05  # Significance level

# Conduct the F-test
F_value, critical_value, decision = conduct_f_test(var1, var2, n1, n2, alpha)

# Output the results
print(f"F-value: {F_value:.4f}")
print(f"Critical F-value at alpha={alpha}: {critical_value:.4f}")
print(f"Decision: {decision}")

# %%
Q5. A manufacturer claims that the variance of the diameter of a certain product is 0.005. A sample of 25
products is taken, and the sample variance is found to be 0.006. Conduct an F-test at the 1% significance
level to determine if the claim is justified.

# %%
import scipy.stats as stats

def conduct_f_test(claimed_variance, sample_variance, n, alpha):
    """
    Conduct an F-test to compare a sample variance to a claimed variance.
    
    Parameters:
    claimed_variance (float): Claimed variance of the population.
    sample_variance (float): Sample variance of the sample.
    n (int): Sample size.
    alpha (float): Significance level.
    
    Returns:
    tuple: F-value, critical F-value, and decision.
    """
    
    # Calculate the F-value
    F_value = sample_variance / claimed_variance

    # Degrees of freedom
    df1 = n - 1  # Degrees of freedom for the sample
    df2 = n - 1  # Degrees of freedom for the claimed variance (considered as a fixed value)

    # Critical F-value from the F-distribution
    critical_value = stats.f.ppf(1 - alpha, df1, df2)

    # Decision
    if F_value > critical_value:
        decision = "Reject the null hypothesis (the variance is significantly greater than the claimed variance)."
    else:
        decision = "Fail to reject the null hypothesis (the claim about the variance is justified)."
    
    return F_value, critical_value, decision

# Given data
claimed_variance = 0.005  # Claimed variance
sample_variance = 0.006    # Sample variance
n = 25                      # Sample size
alpha = 0.01                # Significance level

# Conduct the F-test
F_value, critical_value, decision = conduct_f_test(claimed_variance, sample_variance, n, alpha)

# Output the results
print(f"F-value: {F_value:.4f}")
print(f"Critical F-value at alpha={alpha}: {critical_value:.4f}")
print(f"Decision: {decision}")

# %%
Q6. Write a Python function that takes in the degrees of freedom for the numerator and denominator of an
F-distribution and calculates the mean and variance of the distribution. The function should return the
mean and variance as a tuple.

# %%
def f_distribution_mean_variance(df_numerator, df_denominator):
    """
    Calculate the mean and variance of an F-distribution.

    Parameters:
    df_numerator (int): Degrees of freedom for the numerator.
    df_denominator (int): Degrees of freedom for the denominator.

    Returns:
    tuple: Mean and variance of the F-distribution.
    """
    # Calculate mean
    if df_numerator > 2:
        mean = df_numerator / (df_numerator - 2)
    else:
        mean = None  # Mean is undefined for df1 <= 2

    # Calculate variance
    if df_denominator > 4:
        variance = (2 * (df_denominator**2) * (df_numerator + df_numerator - 2)) / (
            df_numerator * (df_denominator - 2)**2 * (df_denominator - 4))
    else:
        variance = None  # Variance is undefined for df2 <= 4

    return (mean, variance)

# Example usage
df_numerator = 5  # Example degrees of freedom for the numerator
df_denominator = 10  # Example degrees of freedom for the denominator
mean, variance = f_distribution_mean_variance(df_numerator, df_denominator)

print(f"Mean of F-distribution: {mean}")
print(f"Variance of F-distribution: {variance}")

# %%
Q7. A random sample of 10 measurements is taken from a normal population with unknown variance. The
sample variance is found to be 25. Another random sample of 15 measurements is taken from another
normal population with unknown variance, and the sample variance is found to be 20. Conduct an F-test
at the 10% significance level to determine if the variances are significantly different.

# %%
import scipy.stats as stats

def conduct_f_test(sample_variance1, sample_variance2, n1, n2, alpha):
    """
    Conduct an F-test to compare variances of two samples.

    Parameters:
    sample_variance1 (float): Sample variance of population 1.
    sample_variance2 (float): Sample variance of population 2.
    n1 (int): Sample size for population 1.
    n2 (int): Sample size for population 2.
    alpha (float): Significance level.

    Returns:
    tuple: F-value, critical F-value, and decision.
    """
    
    # Calculate the F-value (variance ratio)
    F_value = sample_variance1 / sample_variance2

    # Degrees of freedom
    df1 = n1 - 1  # Degrees of freedom for sample 1
    df2 = n2 - 1  # Degrees of freedom for sample 2

    # Critical F-value from the F-distribution
    critical_value = stats.f.ppf(1 - alpha, df1, df2)

    # Decision
    if F_value > critical_value:
        decision = "Reject the null hypothesis (the variances are significantly different)."
    else:
        decision = "Fail to reject the null hypothesis (the variances are not significantly different)."
    
    return F_value, critical_value, decision

# Given data
sample_variance1 = 25  # Sample variance of population 1
sample_variance2 = 20  # Sample variance of population 2
n1 = 10                 # Sample size for population 1
n2 = 15                 # Sample size for population 2
alpha = 0.10            # Significance level

# Conduct the F-test
F_value, critical_value, decision = conduct_f_test(sample_variance1, sample_variance2, n1, n2, alpha)

# Output the results
print(f"F-value: {F_value:.4f}")
print(f"Critical F-value at alpha={alpha}: {critical_value:.4f}")
print(f"Decision: {decision}")

# %%
Q8. The following data represent the waiting times in minutes at two different restaurants on a Saturday
night: Restaurant A: 24, 25, 28, 23, 22, 20, 27; Restaurant B: 31, 33, 35, 30, 32, 36. Conduct an F-test at the 5%
significance level to determine if the variances are significantly different.

# %%
import numpy as np
import scipy.stats as stats

def conduct_f_test(data1, data2, alpha):
    """
    Conduct an F-test to compare variances of two samples.

    Parameters:
    data1 (list): Sample data for population 1.
    data2 (list): Sample data for population 2.
    alpha (float): Significance level.

    Returns:
    tuple: F-value, critical F-value, and decision.
    """
    
    # Calculate sample variances
    var1 = np.var(data1, ddof=1)  # Sample variance for data1
    var2 = np.var(data2, ddof=1)  # Sample variance for data2

    # Calculate the F-value (variance ratio)
    F_value = var1 / var2 if var1 >= var2 else var2 / var1

    # Degrees of freedom
    df1 = len(data1) - 1  # Degrees of freedom for sample 1
    df2 = len(data2) - 1  # Degrees of freedom for sample 2

    # Critical F-value from the F-distribution
    critical_value = stats.f.ppf(1 - alpha, df1, df2)

    # Decision
    if F_value > critical_value:
        decision = "Reject the null hypothesis (the variances are significantly different)."
    else:
        decision = "Fail to reject the null hypothesis (the variances are not significantly different)."
    
    return F_value, critical_value, decision

# Waiting times at the restaurants
restaurant_a = [24, 25, 28, 23, 22, 20, 27]
restaurant_b = [31, 33, 35, 30, 32, 36]
alpha = 0.05  # Significance level

# Conduct the F-test
F_value, critical_value, decision = conduct_f_test(restaurant_a, restaurant_b, alpha)

# Output the results
print(f"F-value: {F_value:.4f}")
print(f"Critical F-value at alpha={alpha}: {critical_value:.4f}")
print(f"Decision: {decision}")

# %%
Q9. The following data represent the test scores of two groups of students: Group A: 80, 85, 90, 92, 87, 83;
Group B: 75, 78, 82, 79, 81, 84. Conduct an F-test at the 1% significance level to determine if the variances
are significantly different.

# %%
import numpy as np
import scipy.stats as stats

def conduct_f_test(data1, data2, alpha):
    """
    Conduct an F-test to compare variances of two samples.

    Parameters:
    data1 (list): Sample data for population 1.
    data2 (list): Sample data for population 2.
    alpha (float): Significance level.

    Returns:
    tuple: F-value, critical F-value, and decision.
    """
    
    # Calculate sample variances
    var1 = np.var(data1, ddof=1)  # Sample variance for data1
    var2 = np.var(data2, ddof=1)  # Sample variance for data2

    # Calculate the F-value (variance ratio)
    F_value = var1 / var2 if var1 >= var2 else var2 / var1

    # Degrees of freedom
    df1 = len(data1) - 1  # Degrees of freedom for sample 1
    df2 = len(data2) - 1  # Degrees of freedom for sample 2

    # Critical F-value from the F-distribution
    critical_value = stats.f.ppf(1 - alpha, df1, df2)

    # Decision
    if F_value > critical_value:
        decision = "Reject the null hypothesis (the variances are significantly different)."
    else:
        decision = "Fail to reject the null hypothesis (the variances are not significantly different)."
    
    return F_value, critical_value, decision

# Test scores of the groups
group_a = [80, 85, 90, 92, 87, 83]
group_b = [75, 78, 82, 79, 81, 84]
alpha = 0.01  # Significance level

# Conduct the F-test
F_value, critical_value, decision = conduct_f_test(group_a, group_b, alpha)

# Output the results
print(f"F-value: {F_value:.4f}")
print(f"Critical F-value at alpha={alpha}: {critical_value:.4f}")
print(f"Decision: {decision}")
